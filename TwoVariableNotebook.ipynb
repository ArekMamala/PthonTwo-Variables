# %% [markdown]
# # Two Variable plots
# Addapted from [https://matplotlib.org/tutorials/introductory/pyplot.html](https://matplotlib.org/tutorials/introductory/pyplot.html).

# %%
import matplotlib.pyplot as plt
import numpy as npp

# %% [markdown]
# $$ y = 2 x $$

# %%
x = np.linspace(-100, 100.0, 1001)
y =   2.0 * x + 5.0
#y1 =  1.0 / np.exp(x)
y2 = -2.0 * x + 0.0
y3 =  np.exp(x)
y4 = x * x - 4.0 * x + 4.0


plt.plot(x,y, 'k')
#plt.plot(x,y1, 'r')
plt.plot(x,y2, 'b')
#plt.plot(x,y3, 'g')
plt.plot(x,y4, 'g')
